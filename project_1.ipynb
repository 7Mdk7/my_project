# %% [markdown]
# <a href="https://colab.research.google.com/github/7Mdk7/first-project/blob/main/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #import data

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv(r'/content/Global Missing Migrants Dataset.csv')
df1.head(10)
# Out:
#   Incident Type  Incident year Reported Month               Region of Origin  \
# 0      Incident           2014        January                Central America
# 1      Incident           2014        January  Latin America / Caribbean (P)
# 2      Incident           2014        January  Latin America / Caribbean (P)
# 3      Incident           2014        January                Central America
# 4      Incident           2014        January                Northern Africa
# 5      Incident           2014        January  Latin America / Caribbean (P)
# 6      Incident           2014        January                        Unknown
# 7      Incident           2014        January  Latin America / Caribbean (P)
# 8      Incident           2014        January  Latin America / Caribbean (P)
# 9      Incident           2014        January  Latin America / Caribbean (P)
#
#   Region of Incident                 Country of Origin  Number of Dead  \
# ...

# %% [markdown]
# #Understanding data

# %%
df1.describe()
# Out:
#        Incident year  Number of Dead  Minimum Estimated Number of Missing  \
# count   13020.000000    12470.000000                         13020.000000
# mean     2019.060753        2.623737                             1.904378
# std         2.418738        9.728163                            15.645297
# min      2014.000000        0.000000                            -2.000000
# 25%      2017.000000        1.000000                             0.000000
# 50%      2019.000000        1.000000                             0.000000
# 75%      2021.000000        2.000000                             0.000000
# max      2023.000000      750.000000                           750.000000
#
#        Total Number of Dead and Missing  Number of Survivors  \
# count                      13020.000000         13020.000000
# mean                           4.417281             6.553763
# std                           19.950630            42.315444
# ...

# %%
df1.isna().sum()
# Out:
# Incident Type                             0
# Incident year                             0
# Reported Month                            0
# Region of Origin                         22
# Region of Incident                        0
# Country of Origin                         8
# Number of Dead                          550
# Minimum Estimated Number of Missing       0
# Total Number of Dead and Missing          0
# Number of Survivors                       0
# Number of Females                         0
# Number of Males                           0
# Number of Children                        0
# Cause of Death                            0
# Migration route                        3021
# Location of death                         0
# Information Source                        8
# Coordinates                              36
# UNSD Geographical Grouping                1
# dtype: int64

# %% [markdown]
# #missing data

# %%
df1['Region of Origin'].value_counts()
# Out:
# Latin America / Caribbean (P)    2164
# Southern Asia                    1904
# Unknown                          1737
# Central America                  1565
# Sub-Saharan Africa (P)           1528
# Eastern Africa (P)               1133
# Northern Africa                   452
# Western Asia                      432
# South America                     322
# Eastern Africa                    298
# Caribbean                         278
# Western / Southern Asia (P)       245
# Western Africa                    229
# Northern Africa (P)               122
# Sub-Saharan Africa                116
# Mixed                             111
# Southern Asia (P)                  90
# South-eastern Asia                 68
# Western Africa (P)                 52
# Middle Africa                      51
# South America (P)                  18
# Europe                             14
# Western / Southern Asia            14
# Western Asia (P)                   12
# Eastern Asia                       11
# ...

# %%
df1['Region of Origin'].replace(np.nan,'Latin America / Caribbean (P)',inplace=True)
df1.isna().sum()
# Out:
# Incident Type                             0
# Incident year                             0
# Reported Month                            0
# Region of Origin                          0
# Region of Incident                        0
# Country of Origin                         8
# Number of Dead                          550
# Minimum Estimated Number of Missing       0
# Total Number of Dead and Missing          0
# Number of Survivors                       0
# Number of Females                         0
# Number of Males                           0
# Number of Children                        0
# Cause of Death                            0
# Migration route                        3021
# Location of death                         0
# Information Source                        8
# Coordinates                              36
# UNSD Geographical Grouping                1
# dtype: int64

# %%
df1['Country of Origin'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                   Guatemala
# 1                     Unknown
# 2                     Unknown
# 3                      Mexico
# 4                       Sudan
#                  ...
# 13015    Syrian Arab Republic
# 13016                 Unknown
# 13017                 Senegal
# 13018                 Unknown
# 13019                 Unknown
# Name: Country of Origin, Length: 13020, dtype: object>

# %%
df1['Country of Origin'].replace('Unknown',np.nan,inplace=True)

# %%
df1.isna().sum()
# Out:
# Incident Type                             0
# Incident year                             0
# Reported Month                            0
# Region of Origin                          0
# Region of Incident                        0
# Country of Origin                      7228
# Number of Dead                          550
# Minimum Estimated Number of Missing       0
# Total Number of Dead and Missing          0
# Number of Survivors                       0
# Number of Females                         0
# Number of Males                           0
# Number of Children                        0
# Cause of Death                            0
# Migration route                        3021
# Location of death                         0
# Information Source                        8
# Coordinates                              36
# UNSD Geographical Grouping                1
# dtype: int64

# %%
#import pandas as pd
#import numpy as np
#import random

#def replace_nan_with_random(df, column_name, values):
 #   for index, row in df.iterrows():
  #      if pd.isnull(row[column_name]):
   #         random_value = random.choice(values)
    #        df.at[index, column_name] = random_value
    #return df

# Create a sample dataframe with NaN values
#df = pd.DataFrame({'Country of Origin': ['Mexico', np.nan, 'USA', 'Canada', np.nan]})

# Define the values to replace NaN values
#values = ['Mexico', 'Sudan']

# Replace NaN values with random values
#df = replace_nan_with_random(df, 'Country of Origin', values)

# Print the modified dataframe
#print(df)

# %%
#df1['Country of Origin'] = df1['Country of Origin'].apply(lambda x: replace_nan_with_random(df1, 'Country of Origin', values))

# %%
df = pd.DataFrame({'Country of Origin': ['Mexico', np.nan, 'USA', 'Canada', np.nan]})

# Define the values to replace NaN values
values = ['Mexico','Sudan']

# Replace NaN values with random values
df1['Country of Origin'] = df1['Country of Origin'].fillna(pd.Series(np.random.choice(values, size=len(df1.index))))
df1['Country of Origin'].value_counts()
# Out:
# Mexico                                                             7937
# Afghanistan                                                        1702
# Syrian Arab Republic                                                308
# Honduras                                                            307
# Guatemala                                                           297
#                                                                    ...
# Nigeria,Sudan                                                         1
# Mali,Senegal,Unknown                                                  1
# Somalia,Unknown                                                       1
# Cameroon,Côte d'Ivoire,Democratic Republic of the Congo,Tunisia       1
# Gambia,Mali,Nigeria,Senegal,Unknown                                   1
# Name: Country of Origin, Length: 334, dtype: int64

# %%
 num = df1['Number of Dead'].mean().round(2)
 df1['Number of Dead'].replace(np.nan,num,inplace=True)

# %%
df1['Migration route'].value_counts()
# Out:
# US-Mexico border crossing                                3392
# Sahara Desert crossing                                   2046
# Central Mediterranean                                    1106
# Afghanistan to Iran                                      1099
# Western Mediterranean                                     614
# Eastern Mediterranean                                     336
# Western Africa / Atlantic route to the Canary Islands     226
# Western Balkans                                           210
# Horn of Africa to Yemen crossing                          161
# Türkiye-Europe land route                                 157
# English Channel to the UK                                 134
# Syria to Türkiye                                          129
# Darien                                                     98
# Caribbean to US                                            63
# Belarus-EU border                                          61
# ...

# %%
df1['Migration route'].replace(np.nan,'US-Mexico border crossing',inplace=True)

# %%
df1.dropna(subset=['UNSD Geographical Grouping'],axis=0,inplace=True)

# %%
df1.dropna(subset=['Information Source'],axis=0,inplace=True)

# %%
df1.dropna(subset=['Coordinates'],axis=0,inplace=True)

# %%
#df1.to_csv('New data')
df2= pd.read_csv("/content/New data")
df2.head()
# Out:
#    Unnamed: 0 Incident Type  Incident year Reported Month  \
# 0           0      Incident           2014        January
# 1           1      Incident           2014        January
# 2           2      Incident           2014        January
# 3           3      Incident           2014        January
# 4           4      Incident           2014        January
#
#                 Region of Origin Region of Incident Country of Origin  \
# 0                Central America      North America         Guatemala
# 1  Latin America / Caribbean (P)      North America            Mexico
# 2  Latin America / Caribbean (P)      North America            Mexico
# 3                Central America      North America            Mexico
# 4                Northern Africa             Europe             Sudan
#
#    Number of Dead  Minimum Estimated Number of Missing  \
# 0             1.0                                    0
# 1             1.0                                    0
# ...

# %%
df2.isna().sum()
# Out:
# Unnamed: 0                             0
# Incident Type                          0
# Incident year                          0
# Reported Month                         0
# Region of Origin                       0
# Region of Incident                     0
# Country of Origin                      0
# Number of Dead                         0
# Minimum Estimated Number of Missing    0
# Total Number of Dead and Missing       0
# Number of Survivors                    0
# Number of Females                      0
# Number of Males                        0
# Number of Children                     0
# Cause of Death                         0
# Migration route                        0
# Location of death                      0
# Information Source                     0
# Coordinates                            0
# UNSD Geographical Grouping             0
# dtype: int64

# %%
df2.drop('Unnamed: 0',axis=1)
df2
# Out:
#        Unnamed: 0 Incident Type  Incident year Reported Month  \
# 0               0      Incident           2014        January
# 1               1      Incident           2014        January
# 2               2      Incident           2014        January
# 3               3      Incident           2014        January
# 4               4      Incident           2014        January
# ...           ...           ...            ...            ...
# 12971       13015      Incident           2023           July
# 12972       13016      Incident           2023           July
# 12973       13017      Incident           2023           July
# 12974       13018      Incident           2023           July
# 12975       13019      Incident           2023           July
#
#                     Region of Origin Region of Incident     Country of Origin  \
# 0                    Central America      North America             Guatemala
# ...

# %% [markdown]
# #exploring data analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df2)

# %%
plt.barh("Number of Females" ,"Incident year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
